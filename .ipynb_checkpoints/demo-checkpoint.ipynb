# %% [markdown]
# ### a) Imports

# %%
import matplotlib.pyplot as plt
from sklearn import linear_model, datasets
import os
import simplejson
import sys
import numpy as np
from sklearn.datasets import load_svmlight_file
import importlib as imp
import loss_functions
if 'loss_functions' not in sys.modules:
    import loss_functions
else:
    imp.reload(loss_functions) 
    
if 'make_plots' not in sys.modules:
    import make_plots
else:
    imp.reload(make_plots) 
    
if 'scr' not in sys.modules:
    import scr
else:
    imp.reload(scr) 
        
if 'tr' not in sys.modules:
    import tr
else:
    imp.reload(tr)
    
if 'sgd' not in sys.modules:
    import sgd
else:
    imp.reload(sgd)

if 'SAGA' not in sys.modules:
    import sgd
else:
    imp.reload(sgd)

# %% [markdown]
# ### b) load data and initialize weights

# %%
#####################
#### Load  Data  ####
#####################

dataset_name='a9a' 

#logistic regression:
if dataset_name=='a9a':
    X, Y = load_svmlight_file('data/a9a')
    X = X.toarray()
    Y= [0 if e == -1 else e for e in Y]
    Y=np.array(Y)      
    d = X.shape[1]
    n = X.shape[0]
    w = np.zeros(d)
    
#multinominal (softmax) regression:
elif dataset_name == 'mnist':
    import scipy 
    X, Y = load_svmlight_file('data/mnist')
    X = X.toarray()
    nC = len(np.unique(Y))    
    ## one-hot encoding of labels
    data   = np.ones(len(Y))
    indptr = np.arange(len(Y)+1)
    ground_truth = scipy.sparse.csr_matrix((data, Y, indptr))
    Y = ground_truth.todense() #gives a matrix with [Ground_Truth]i,j: is sample i in class j? (n x nC)
    d = X.shape[1]
    n = X.shape[0]
    w = np.zeros(nC*d)

#general function    
elif dataset_name=='rosenbrock':
    d=2
    n=1 
    w = np.zeros(d)

print ('Dataset', dataset_name, 'loaded')    
print ('n = ' + str(n) + ' d = ' + str(d))
# Out:
# Dataset a9a loaded
# n = 32561 d = 123

# %% [markdown]
# ### c) specify a loss, gradient, Hessian-vector-product and Hessian computations
# - (latter only needed for hard case)
# - functions need to have (w,X,Y,kwargs...) as input structure !

# %%
if dataset_name in {'a9a'}:
    loss_computation = loss_functions.logistic_loss
    gradient_computation = loss_functions.logistic_loss_gradient
    hessian_vector_computation = loss_functions.logistic_loss_Hv
    hessian_computation = loss_functions.logistic_loss_hessian
    
    # Additional arguments that are to be passed to the Loss, Gradient, etc. computations
    loss_args= {}
    loss_args['alpha'] = 1e-3 # regularizer

if dataset_name in {'mnist'}:
    loss_computation = loss_functions.softmax_loss
    gradient_computation = loss_functions.softmax_loss_gradient
    hessian_vector_computation = loss_functions.softmax_loss_Hv
    hessian_computation = loss_functions.softmax_loss_hessian
    
    loss_args= {}
    loss_args['alpha'] = 1e-3
    loss_args['n_classes'] = nC # for multiclass (softmax) regression

    
elif dataset_name == 'rosenbrock':
    loss_computation = loss_functions.rosenbrock_loss
    gradient_computation = loss_functions.rosenbrock_gradient
    hessian_vector_computation = loss_functions.rosenbrock_Hv
    hessian_computation = loss_functions.rosenbrock_hessian
    
    loss_args= {}

# %%
def show_plots(x_limits_time=None):
    list_params=[]
    list_loss=[]
    list_x=[]
    list_samples=[]
    
    log_scale=True
    
    over_time=True
    over_iterations=True
    over_epochs=True
    
    if SCR:
        list_loss.append(SCR_loss)
        list_x.append(SCR_x)
        list_samples.append(SCR_samples)
        list_params.append('SCR')
        
    if TR:
        list_loss.append(TR_loss)
        list_x.append(TR_x)
        list_samples.append(TR_samples)
        list_params.append('TR')
        
    if SGD:
        list_loss.append(SGD_loss)
        list_x.append(SGD_x)
        list_samples.append(SGD_samples)
        list_params.append('SGD')
        
    if over_time:
        make_plots.two_d_plot_time(list_loss,list_x,list_params,dataset_name, n, d, log_scale,x_limits=x_limits_time)
        
    if over_iterations:
        make_plots.two_d_plot_iterations(list_loss,list_x,list_params,dataset_name, n, d, log_scale)
        
    if over_epochs:
        make_plots.two_d_plot_epochs(list_loss,list_samples,list_params,dataset_name, n, d, log_scale)

# %% [markdown]
# ### d) Set parameters and run methods

# %%
n_runs = 1 # repeat experiments to lower effect of randomness

# The following parameters are optional in the sense that default values are set if not specified.
opt = {}

### TR and SCR:
opt['penalty_increase_multiplier']=2.    # multiply by..
opt['penalty_derease_multiplier']=2.     # divide by..
opt['initial_penalty_parameter']=0.01
opt['initial_tr_radius']=1
opt['successful_treshold']=0.1
opt['very_successful_treshold']=0.9

opt['grad_tol']=1e-9
opt['n_iterations'] = 20

# Sampling
opt['Hessian_sampling']=True
opt['gradient_sampling']=False
opt['initial_sample_size_Hessian']=0.025
opt['initial_sample_size_gradient']=0.25
opt['subproblem_solver']='lanczos'
opt['unsuccessful_sample_scaling']=1.5
opt['sample_scaling_Hessian']=1
opt['sample_scaling_gradient']=1

# Subproblem 
opt['subproblem_solver_SCR']='lanczos' # alternatives: lanczos, cauchy_point, exact
opt['subproblem_solver_TR']='GLTR' # alternatives: GLTR, cauchy_point, exact, dog_leg, cg

opt['solve_each_i-th_krylov_space']=1   
opt['krylov_tol']=1e-1
opt['exact_tol']=1e-2
opt['keep_Q_matrix_in_memory']=True

### SGD:
opt['n_epochs_sgd']=10
opt['learning_rate_sgd']=1e-1
opt['batch_size_sgd']=0.001*n




######################
#### Run Methods #####
######################

SCR=True
TR= True
SGD= True

if SCR:
    loss_collector=[]
    timings_collector=[]
    samples_collector=[]
    
    for k in range(n_runs): 
        SCR_loss=[]
        SCR_x=[]
        (w_SCR,_timing, _loss, _samples)=scr.SCR(w,loss_computation,gradient_computation,
                                                    Hv=hessian_vector_computation,hessian=hessian_computation, X=X, Y=Y, opt=opt, **loss_args)
        loss_collector.append(_loss)
        timings_collector.append(_timing)
        samples_collector.append(_samples)

    SCR_loss = [float(sum(col))/len(col) for col in zip(*loss_collector)]
    SCR_x = [float(sum(col))/len(col) for col in zip(*timings_collector)]    
    SCR_samples= [float(sum(col))/len(col) for col in zip(*samples_collector)] 
    
if TR:
    loss_collector=[]
    timings_collector=[]
    samples_collector=[]
    
    for k in range(n_runs): 
        TR_loss=[]
        TR_x=[]
        (w_TR,_timing, _loss, _samples)=tr.Trust_Region(w,loss_computation,gradient_computation,
                                                    Hv=hessian_vector_computation, hessian=hessian_computation, X=X, Y=Y, opt=opt, **loss_args)
        loss_collector.append(_loss)
        timings_collector.append(_timing)
        samples_collector.append(_samples)

    TR_loss = [float(sum(col))/len(col) for col in zip(*loss_collector)]
    TR_x = [float(sum(col))/len(col) for col in zip(*timings_collector)]    
    TR_samples= [float(sum(col))/len(col) for col in zip(*samples_collector)] 
    
if SGD:
    loss_collector=[]
    timings_collector=[]
    samples_collector=[]
    
    for k in range(n_runs): 
        SGD_loss=[]
        SGD_x=[]
        (w_SGD,_timing, _loss, _samples)=sgd.SGD(w,loss_computation,gradient_computation, X=X, Y=Y, opt=opt, **loss_args)
        loss_collector.append(_loss)
        timings_collector.append(_timing)
        samples_collector.append(_samples)

    SGD_loss = [float(sum(col))/len(col) for col in zip(*loss_collector)]
    SGD_x = [float(sum(col))/len(col) for col in zip(*timings_collector)]    
    SGD_samples= [float(sum(col))/len(col) for col in zip(*samples_collector)]
# Out:
# --- Subsampled Cubic Regularization ---
#
# - Subproblem_solver: lanczos
# - Hessian_sampling: True
# - Gradient_sampling: False
# - Sampling_scheme: adaptive
#
# Iteration 0: loss = 0.421908853537 norm_grad = 0.673770075892 time=  0.024 penalty= 0.005 stepnorm= 1.05615261903 Samples Hessian= 814 samples Gradient= 32561
#
# Iteration 1: loss = 0.354695614552 norm_grad = 0.146319152316 time=  0.03 penalty= 0.0025 stepnorm= 1.37891028166 Samples Hessian= 814 samples Gradient= 32561
#
# Iteration 2: loss = 0.337808534444 norm_grad = 0.0430846814518 time=  0.029 penalty= 0.00125 stepnorm= 1.07516185054 Samples Hessian= 814 samples Gradient= 32561
#
# Iteration 3: loss = 0.333747424257 norm_grad = 0.0125669260034 time=  0.032 penalty= 0.000625 stepnorm= 0.922119430576 Samples Hessian= 814 samples Gradient= 32561
#
# Iteration 4: loss = 0.333367281182 norm_grad = 0.00495943669079 time=  0.047 penalty= 0.0003125 stepnorm= 0.415538923807 Samples Hessian= 1067 samples Gradient= 32561
#
# Iteration 5: loss = 0.333341405763 norm_grad = 0.000655440081908 time=  0.089 penalty= 0.00015625 stepnorm= 0.150072466583 Samples Hessian= 5258 samples Gradient= 32561
#
# Iteration 6: loss = 0.333340752585 norm_grad = 0.000135221747929 time=  0.184 penalty= 7.8125e-05 stepnorm= 0.02248273572 Samples Hessian= 32561 samples Gradient= 32561
#
# Iteration 7: loss = 0.333340752069 norm_grad = 2.12947628068e-06 time=  0.34 penalty= 3.90625e-05 stepnorm= 0.000735887061217 Samples Hessian= 32561 samples Gradient= 32561
#
# Iteration 8: loss = 0.333340752069 norm_grad = 1.28794950319e-09 time=  0.621 penalty= 3.90625e-05 stepnorm= 4.56943794117e-07 Samples Hessian= 32561 samples Gradient= 32561
#
# --- Trust Region ---
#
# - Subproblem_solver: GLTR
# - Hessian_sampling: True
# - Gradient_sampling: False
# - Sampling_scheme: exponential
#
# Iteration 0: loss = 0.425978886215 norm_grad = 0.152519696986 time=  0.025256 tr_radius= 1 stepnorm= 1.00169056483 Samples Hessian= 816 samples Gradient= 32561
#
# Iteration 1: loss = 0.372341174573 norm_grad = 0.0563920466846 time=  0.029593 tr_radius= 1 stepnorm= 0.80973990383 Samples Hessian= 817 samples Gradient= 32561
#
# Iteration 2: loss = 0.341324405823 norm_grad = 0.0205613931133 time=  0.030778999999999994 tr_radius= 2.0 stepnorm= 1.4731778719 Samples Hessian= 819 samples Gradient= 32561
#
# Iteration 3: loss = 0.334115143325 norm_grad = 0.00482471855143 time=  0.030872999999999998 tr_radius= 4.0 stepnorm= 1.26873281379 Samples Hessian= 822 samples Gradient= 32561
#
# Iteration 4: loss = 0.33345434281 norm_grad = 0.00230133141917 time=  0.076522 tr_radius= 8.0 stepnorm= 0.691133083352 Samples Hessian= 828 samples Gradient= 32561
#
# Iteration 5: loss = 0.333352159095 norm_grad = 0.000591089880097 time=  0.11937799999999998 tr_radius= 8.0 stepnorm= 0.254651505131 Samples Hessian= 837 samples Gradient= 32561
#
# Iteration 6: loss = 0.333341806264 norm_grad = 0.000229274256788 time=  0.141337 tr_radius= 8.0 stepnorm= 0.0712479055823 Samples Hessian= 852 samples Gradient= 32561
#
# Iteration 7: loss = 0.333340865866 norm_grad = 9.70532534544e-05 time=  0.14274600000000004 tr_radius= 8.0 stepnorm= 0.0265408662704 Samples Hessian= 878 samples Gradient= 32561
#
# Iteration 8: loss = 0.333340764968 norm_grad = 3.09025492893e-05 time=  0.13917800000000002 tr_radius= 8.0 stepnorm= 0.00834551945089 Samples Hessian= 921 samples Gradient= 32561
#
# Iteration 9: loss = 0.333340753467 norm_grad = 6.45346765412e-06 time=  0.11784299999999992 tr_radius= 8.0 stepnorm= 0.00325649281152 Samples Hessian= 993 samples Gradient= 32561
#
# Iteration 10: loss = 0.333340752196 norm_grad = 2.2113267273e-06 time=  0.06525200000000009 tr_radius= 8.0 stepnorm= 0.000950995388338 Samples Hessian= 1114 samples Gradient= 32561
#
# Iteration 11: loss = 0.333340752079 norm_grad = 5.23178376553e-07 time=  0.08572899999999994 tr_radius= 8.0 stepnorm= 0.00027541412911 Samples Hessian= 1317 samples Gradient= 32561
#
# Iteration 12: loss = 0.333340752069 norm_grad = 2.04816840791e-07 time=  0.07037300000000002 tr_radius= 8.0 stepnorm= 7.52376274355e-05 Samples Hessian= 1658 samples Gradient= 32561
#
# Iteration 13: loss = 0.333340752069 norm_grad = 2.65395850313e-08 time=  0.04472000000000009 tr_radius= 8.0 stepnorm= 1.73378751895e-05 Samples Hessian= 2231 samples Gradient= 32561
#
# Iteration 14: loss = 0.333340752069 norm_grad = 5.12923132456e-09 time=  0.04820599999999997 tr_radius= 16.0 stepnorm= 4.1291655719e-06 Samples Hessian= 3193 samples Gradient= 32561
#
# --- SGD ---
# Epoch 1: loss = 0.69314718056 norm_grad = 0.495832239144 time= 0.001
# Epoch 2: loss = 0.341236984534 norm_grad = 0.264365718791 time= 1.023
# Epoch 3: loss = 0.336448873042 norm_grad = 0.150860246622 time= 1.114
# Epoch 4: loss = 0.335110391759 norm_grad = 0.145052314317 time= 0.963
# Epoch 5: loss = 0.334159434536 norm_grad = 0.168155024838 time= 0.914
# Epoch 6: loss = 0.33742153419 norm_grad = 0.167385150414 time= 0.918
# Epoch 7: loss = 0.334004318606 norm_grad = 0.134059883025 time= 0.936
# Epoch 8: loss = 0.33395007634 norm_grad = 0.147843647414 time= 0.948
# Epoch 9: loss = 0.334141590956 norm_grad = 0.221532830342 time= 1.024
# Epoch 10: loss = 0.334996270109 norm_grad = 0.116228379744 time= 0.92

# %%
# %matplotlib inline
show_plots(x_limits_time=(0,1.5))
